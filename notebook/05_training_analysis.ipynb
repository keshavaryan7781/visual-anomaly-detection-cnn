# %%
import sys
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
import tensorflow as tf
from src.data_loader import get_train_paths, build_train_dataset
from src.models.autoencoder import build_autoencoder

# %%
category = "bottle"
train_path = get_train_paths(category=category)
train_ds = build_train_dataset(train_path)

train_ds = train_ds.map(lambda x: (x, x))

autoencoder = build_autoencoder()

# %%
autoencoder.compile(
    optimizer = tf.keras.optimizers.Adam(1e-3),
    loss = "mse"
)

# %%
history = autoencoder.fit(
    train_ds,
    epochs=100,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor="loss",
            patience=10,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - loss: 0.0578
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 0.0034
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 0.0022
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 0.0017
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 0.0014
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 0.0013
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - loss: 0.0012
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - loss: 0.0012
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 0.0011
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 0.0010
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 0.0010
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 9.7085e-04
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 9.5543e-04
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - loss: 9.3321e-04
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 9.1478e-04
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - loss: 8.9217e-04
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - loss: 8.8559e-04
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - loss: 8.7713e-04
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - loss: 8.5736e-04
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - loss: 8.3498e-04
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - loss: 8.2582e-04
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - loss: 8.1424e-04
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 3s/step - loss: 8.0817e-04
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - loss: 8.5378e-04
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 8.1832e-04
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.8645e-04
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 8.0097e-04
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.7594e-04
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.7814e-04
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.7574e-04
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.6449e-04
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.5690e-04
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.5931e-04
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.4715e-04
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.4050e-04
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 7.3349e-04
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.7250e-04
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.2660e-04
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.1716e-04
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.0378e-04
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.1098e-04
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - loss: 7.0371e-04
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.9660e-04
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.0005e-04
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.9368e-04
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.9910e-04
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.7492e-04
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.9842e-04
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.7037e-04
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.2305e-04
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 7.0521e-04
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.8688e-04
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.6484e-04
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.9575e-04
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.6833e-04
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.5903e-04
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.5401e-04
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.4183e-04
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.4578e-04
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.5262e-04
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.8288e-04
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.3894e-04
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.4723e-04
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.5940e-04
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.4261e-04
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.3147e-04
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.2544e-04
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.2215e-04
# Epoch 69/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.2397e-04
# Epoch 70/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.2715e-04
# Epoch 71/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.1585e-04
# Epoch 72/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.4510e-04
# Epoch 73/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.1319e-04
# Epoch 74/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 6.0431e-04
# Epoch 75/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.0876e-04
# Epoch 76/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.0861e-04
# Epoch 77/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.0328e-04
# Epoch 78/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.1452e-04
# Epoch 79/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.4348e-04
# Epoch 80/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.3025e-04
# Epoch 81/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.2808e-04
# Epoch 82/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.9616e-04
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.3210e-04
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.0630e-04
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.0603e-04
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 6.1125e-04
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step - loss: 5.9024e-04
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.8698e-04
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.7155e-04
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.9203e-04
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.7122e-04
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.7928e-04
# Epoch 93/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.8062e-04
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 6.3553e-04
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 5.7652e-04
# Epoch 96/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 5.6955e-04
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 26s 2s/step - loss: 5.6845e-04
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 27s 2s/step - loss: 5.7330e-04
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 28s 2s/step - loss: 5.8073e-04
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - loss: 5.6598e-04
